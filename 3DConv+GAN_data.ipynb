# %%
import numpy as np
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import pandas as pd
data = np.load(r"/content/drive/My Drive/Marko/Model_learning/GAN/HSI-Classification-GAN/dataset/ds.npy")
gt = np.load(r"/content/drive/My Drive/Marko/Model_learning/GAN/HSI-Classification-GAN/dataset/gt.npy")
print(data.shape)
print(gt.shape)
# Out:
# (145, 145, 200)
# (145, 145)

# %%
H = data.shape[0]
W = data.shape[1]
#归一化
scaler = StandardScaler()
voxel = scaler.fit_transform(data.reshape(-1, data.shape[-1]))
print(voxel.shape)
#PCA 
pca = PCA(n_components=30)
principalComponents = pca.fit_transform(voxel)
print(principalComponents.shape)
# principalDF = pd.DataFrame(data=principalComponents, columns=["pc%d"%x for x in range(30)])
# print(principalDF)
fullDataX = principalComponents.reshape(H,W,30)
fullDataY = gt
print("fullDataX:",fullDataX.shape)
print("fullDataY:",gt.shape)
# Out:
# (21025, 200)
# (21025, 30)
# fullDataX: (145, 145, 30)
# fullDataY: (145, 145)

# %%
import cv2
from skimage.util import view_as_windows
np.random.seed(666)
print(fullDataX.shape)
#(145,145,30) -> (176,176,30)
paddedDatax = cv2.copyMakeBorder(fullDataX, 16, 15, 16, 15, cv2.BORDER_CONSTANT, value=0)
print(paddedDatax.shape)
#(176,176,30) -> (145,145,1,32,32,30) 176-32+1=145 || 3-3+1=1
X_train = view_as_windows(paddedDatax, (32, 32, 30), step=1).reshape(-1,32,32,30)
#(145,145,1,32,32,30) -> (21025,32,32,03)
y_train = fullDataY.reshape(-1,)
p = np.random.permutation(len(X_train))
X_train=X_train[p]
y_train=y_train[p]
print(X_train.shape)
print(y_train.shape)
# Out:
# (145, 145, 30)
# (176, 176, 30)
# (21025, 32, 32, 30)
# (21025,)

# %%
X_train = X_train[y_train>0,:,:,:]
y_train = y_train[y_train>0]
y_train = y_train - 1 #1-17 -> 0-16
print(X_train.shape)
print(y_train.shape)
data = X_train
label = y_train
# Out:
# (10249, 32, 32, 30)
# (10249,)

# %%
GAN_data = np.load(r"/content/drive/My Drive/Marko/Model_learning/GAN/HSI-Classification-GAN/EI_PAPER/New_data_generated_by_GAN/generated_data.npy")
GAN_label = np.load(r"/content/drive/My Drive/Marko/Model_learning/GAN/HSI-Classification-GAN/EI_PAPER/New_data_generated_by_GAN/generated_label.npy")
GAN_label = GAN_label - 1
print(GAN_data.shape)
print(GAN_label.shape)
# Out:
# (10249, 32, 32, 30)
# (10249,)

# %%
all_data = np.concatenate((X_train, GAN_data))
all_label = np.concatenate((y_train, GAN_label))
print(all_data.shape)
print(all_label.shape)
# Out:
# (20498, 32, 32, 30)
# (20498,)

# %%
from sklearn.model_selection import train_test_split
import tensorflow as tf

tf.random.set_seed(666)
batch_sz=32
X, test_data, Y, test_label = train_test_split(all_data, all_label, test_size=0.3, random_state=666)
train_data, valid_data, train_label, valid_label = train_test_split(X, Y, test_size=0.2, random_state=666)

train_data = train_data.reshape(-1,32,32,30,1)
valid_data = valid_data.reshape(-1,32,32,30,1)
test_data = test_data.reshape(-1,32,32,30,1)
print(train_data.shape, train_label.shape)
print(valid_data.shape, valid_label.shape)
print(test_data.shape, test_label.shape)
# Out:
# (11478, 32, 32, 30, 1) (11478,)
# (2870, 32, 32, 30, 1) (2870,)
# (6150, 32, 32, 30, 1) (6150,)

# %% [markdown]
# ## Model_define

# %%
from tensorflow.keras.layers import Dense, Conv3D, Conv2D, Flatten, Reshape, Dropout, Input, Activation, BatchNormalization, MaxPool3D
from tensorflow.keras.models import Model
import tensorflow as tf
#input_layer = (32,32,30,1)
input_layer = Input(shape=(32,32,30,1))
#Conv3D_layer

Conv1 = Conv3D(filters=16, kernel_size=(3,3,3), strides=(2,2,2))(input_layer)
Bn1 = BatchNormalization()(Conv1)
LR1 = tf.nn.leaky_relu(Bn1,alpha=0.2)
Pool1 = MaxPool3D(pool_size=(2,2,2))(LR1)

Conv2 = Conv3D(filters=32, kernel_size=(3,3,3), strides=(2,2,2))(Pool1)
Bn2 = BatchNormalization()(Conv2)
LR2 = tf.nn.leaky_relu(Bn2,alpha=0.2)
Pool2 = MaxPool3D(pool_size=(2,2,2))(LR2)

flatten_layer = Flatten()(Pool2)

fc = Dense(units=16, activation="softmax")(flatten_layer)

Conv3D_net = Model(input_layer, fc)

# %%
Conv3D_net.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 32, 30, 1)]   0
# _________________________________________________________________
# conv3d (Conv3D)              (None, 15, 15, 14, 16)    448
# _________________________________________________________________
# batch_normalization (BatchNo (None, 15, 15, 14, 16)    64
# _________________________________________________________________
# tf_op_layer_LeakyRelu (Tenso [(None, 15, 15, 14, 16)]  0
# _________________________________________________________________
# max_pooling3d (MaxPooling3D) (None, 7, 7, 7, 16)       0
# _________________________________________________________________
# conv3d_1 (Conv3D)            (None, 3, 3, 3, 32)       13856
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 3, 3, 3, 32)       128
# _________________________________________________________________
# tf_op_layer_LeakyRelu_1 (Ten [(None, 3, 3, 3, 32)]     0
# _________________________________________________________________
# max_pooling3d_1 (MaxPooling3 (None, 1, 1, 1, 32)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 32)                0
# _________________________________________________________________
# dense (Dense)                (None, 16)                528
# =================================================================
# Total params: 15,024
# Trainable params: 14,928
# Non-trainable params: 96
# _________________________________________________________________

# %%
from tensorflow.keras import optimizers
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
import os 
path = r"/content/drive/My Drive/Marko/Model_learning/GAN/HSI-Classification-GAN/EI_PAPER/weights_and_models"
save = os.path.join(path,"best_Conv3D_net+GAN_data.h5")

adam = optimizers.Adam(learning_rate=0.0005, decay=1e-6)
checkpoint = ModelCheckpoint(save, monitor='acc', verbose=0, save_best_only=True, mode='max')
earlystopping = EarlyStopping(patience=10, min_delta=1e-4)
callbacks_list = [checkpoint,earlystopping]
Conv3D_net.compile(loss='sparse_categorical_crossentropy', optimizer=adam, metrics=['accuracy'])
Conv3D_net.load_weights(save)

# %%
batch_sz=128
os.environ["TF_CPP_MIN_LOG_LEVEL"]="3"
history = Conv3D_net.fit(train_data, train_label,
              epochs=100,
              batch_size=batch_sz,
              validation_data=(valid_data, valid_label),
              callbacks=callbacks_list)
# Out:
# Epoch 1/100
# 89/90 [============================>.] - ETA: 0s - loss: 0.0024 - accuracy: 0.9995WARNING:tensorflow:Can save best model only with acc available, skipping.
# 90/90 [==============================] - 2s 20ms/step - loss: 0.0024 - accuracy: 0.9995 - val_loss: 0.0266 - val_accuracy: 0.9906
# Epoch 2/100
# 89/90 [============================>.] - ETA: 0s - loss: 0.0056 - accuracy: 0.9989WARNING:tensorflow:Can save best model only with acc available, skipping.
# 90/90 [==============================] - 2s 18ms/step - loss: 0.0056 - accuracy: 0.9990 - val_loss: 0.0381 - val_accuracy: 0.9906
# Epoch 3/100
# 89/90 [============================>.] - ETA: 0s - loss: 0.0012 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with acc available, skipping.
# 90/90 [==============================] - 2s 18ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0143 - val_accuracy: 0.9951
# Epoch 4/100
# 89/90 [============================>.] - ETA: 0s - loss: 6.8031e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with acc available, skipping.
# 90/90 [==============================] - 2s 19ms/step - loss: 6.7790e-04 - accuracy: 1.0000 - val_loss: 0.0125 - val_accuracy: 0.9955
# Epoch 5/100
# 89/90 [============================>.] - ETA: 0s - loss: 5.6473e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with acc available, skipping.
# 90/90 [==============================] - 2s 20ms/step - loss: 5.6446e-04 - accuracy: 1.0000 - val_loss: 0.0127 - val_accuracy: 0.9948
# Epoch 6/100
# 89/90 [============================>.] - ETA: 0s - loss: 4.9417e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with acc available, skipping.
# 90/90 [==============================] - 2s 20ms/step - loss: 4.9253e-04 - accuracy: 1.0000 - val_loss: 0.0126 - val_accuracy: 0.9955
# Epoch 7/100
# 89/90 [============================>.] - ETA: 0s - loss: 4.4356e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with acc available, skipping.
# 90/90 [==============================] - 2s 20ms/step - loss: 4.4370e-04 - accuracy: 1.0000 - val_loss: 0.0123 - val_accuracy: 0.9955
# Epoch 8/100
# 89/90 [============================>.] - ETA: 0s - loss: 3.9825e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with acc available, skipping.
# 90/90 [==============================] - 2s 20ms/step - loss: 3.9710e-04 - accuracy: 1.0000 - val_loss: 0.0125 - val_accuracy: 0.9948
# Epoch 9/100
# 89/90 [============================>.] - ETA: 0s - loss: 3.6862e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with acc available, skipping.
# 90/90 [==============================] - 2s 23ms/step - loss: 3.6873e-04 - accuracy: 1.0000 - val_loss: 0.0129 - val_accuracy: 0.9951
# Epoch 10/100
# 89/90 [============================>.] - ETA: 0s - loss: 3.3159e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with acc available, skipping.
# 90/90 [==============================] - 5s 58ms/step - loss: 3.3102e-04 - accuracy: 1.0000 - val_loss: 0.0122 - val_accuracy: 0.9951
# Epoch 11/100
# 89/90 [============================>.] - ETA: 0s - loss: 3.0576e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with acc available, skipping.
# 90/90 [==============================] - 2s 18ms/step - loss: 3.0552e-04 - accuracy: 1.0000 - val_loss: 0.0127 - val_accuracy: 0.9951
# Epoch 12/100
# 89/90 [============================>.] - ETA: 0s - loss: 2.8830e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with acc available, skipping.
# 90/90 [==============================] - 2s 18ms/step - loss: 2.8874e-04 - accuracy: 1.0000 - val_loss: 0.0123 - val_accuracy: 0.9955
# Epoch 13/100
# 89/90 [============================>.] - ETA: 0s - loss: 2.6824e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with acc available, skipping.
# 90/90 [==============================] - 2s 18ms/step - loss: 2.6851e-04 - accuracy: 1.0000 - val_loss: 0.0122 - val_accuracy: 0.9951
# Epoch 14/100
# 89/90 [============================>.] - ETA: 0s - loss: 2.5170e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with acc available, skipping.
# 90/90 [==============================] - 2s 18ms/step - loss: 2.5243e-04 - accuracy: 1.0000 - val_loss: 0.0123 - val_accuracy: 0.9948
# Epoch 15/100
# 89/90 [============================>.] - ETA: 0s - loss: 2.3569e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with acc available, skipping.
# 90/90 [==============================] - 2s 18ms/step - loss: 2.3631e-04 - accuracy: 1.0000 - val_loss: 0.0129 - val_accuracy: 0.9955
# Epoch 16/100
# 89/90 [============================>.] - ETA: 0s - loss: 2.1925e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with acc available, skipping.
# 90/90 [==============================] - 2s 18ms/step - loss: 2.1845e-04 - accuracy: 1.0000 - val_loss: 0.0124 - val_accuracy: 0.9951
# Epoch 17/100
# 89/90 [============================>.] - ETA: 0s - loss: 2.0617e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with acc available, skipping.
# 90/90 [==============================] - 2s 18ms/step - loss: 2.0632e-04 - accuracy: 1.0000 - val_loss: 0.0119 - val_accuracy: 0.9951
# Epoch 18/100
# 89/90 [============================>.] - ETA: 0s - loss: 1.9757e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with acc available, skipping.
# 90/90 [==============================] - 2s 22ms/step - loss: 1.9785e-04 - accuracy: 1.0000 - val_loss: 0.0130 - val_accuracy: 0.9944
# Epoch 19/100
# 89/90 [============================>.] - ETA: 0s - loss: 1.8313e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with acc available, skipping.
# 90/90 [==============================] - 2s 23ms/step - loss: 1.8289e-04 - accuracy: 1.0000 - val_loss: 0.0122 - val_accuracy: 0.9948
# Epoch 20/100
# 89/90 [============================>.] - ETA: 0s - loss: 1.8016e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with acc available, skipping.
# 90/90 [==============================] - 2s 18ms/step - loss: 1.7986e-04 - accuracy: 1.0000 - val_loss: 0.0127 - val_accuracy: 0.9948
# Epoch 21/100
# 89/90 [============================>.] - ETA: 0s - loss: 1.6930e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with acc available, skipping.
# 90/90 [==============================] - 2s 18ms/step - loss: 1.6929e-04 - accuracy: 1.0000 - val_loss: 0.0127 - val_accuracy: 0.9948
# Epoch 22/100
# 89/90 [============================>.] - ETA: 0s - loss: 1.5710e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with acc available, skipping.
# 90/90 [==============================] - 2s 18ms/step - loss: 1.5719e-04 - accuracy: 1.0000 - val_loss: 0.0119 - val_accuracy: 0.9955
# Epoch 23/100
# 89/90 [============================>.] - ETA: 0s - loss: 1.4507e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with acc available, skipping.
# 90/90 [==============================] - 2s 18ms/step - loss: 1.4555e-04 - accuracy: 1.0000 - val_loss: 0.0125 - val_accuracy: 0.9944
# Epoch 24/100
# 89/90 [============================>.] - ETA: 0s - loss: 1.4167e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with acc available, skipping.
# 90/90 [==============================] - 2s 18ms/step - loss: 1.4200e-04 - accuracy: 1.0000 - val_loss: 0.0120 - val_accuracy: 0.9948
# Epoch 25/100
# 89/90 [============================>.] - ETA: 0s - loss: 1.3038e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with acc available, skipping.
# 90/90 [==============================] - 2s 18ms/step - loss: 1.2985e-04 - accuracy: 1.0000 - val_loss: 0.0131 - val_accuracy: 0.9944
# Epoch 26/100
# 89/90 [============================>.] - ETA: 0s - loss: 1.2649e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with acc available, skipping.
# 90/90 [==============================] - 2s 18ms/step - loss: 1.2602e-04 - accuracy: 1.0000 - val_loss: 0.0122 - val_accuracy: 0.9948
# Epoch 27/100
# 89/90 [============================>.] - ETA: 0s - loss: 1.1963e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with acc available, skipping.
# 90/90 [==============================] - 2s 18ms/step - loss: 1.1965e-04 - accuracy: 1.0000 - val_loss: 0.0117 - val_accuracy: 0.9951
# Epoch 28/100
# 89/90 [============================>.] - ETA: 0s - loss: 1.1302e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with acc available, skipping.
# 90/90 [==============================] - 3s 29ms/step - loss: 1.1311e-04 - accuracy: 1.0000 - val_loss: 0.0121 - val_accuracy: 0.9951
# Epoch 29/100
# 89/90 [============================>.] - ETA: 0s - loss: 1.1041e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with acc available, skipping.
# 90/90 [==============================] - 2s 17ms/step - loss: 1.1050e-04 - accuracy: 1.0000 - val_loss: 0.0122 - val_accuracy: 0.9951
# Epoch 30/100
# 89/90 [============================>.] - ETA: 0s - loss: 1.0328e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with acc available, skipping.
# 90/90 [==============================] - 2s 18ms/step - loss: 1.0391e-04 - accuracy: 1.0000 - val_loss: 0.0123 - val_accuracy: 0.9955
# Epoch 31/100
# 89/90 [============================>.] - ETA: 0s - loss: 1.0093e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with acc available, skipping.
# 90/90 [==============================] - 2s 18ms/step - loss: 1.0069e-04 - accuracy: 1.0000 - val_loss: 0.0121 - val_accuracy: 0.9944
# Epoch 32/100
# 89/90 [============================>.] - ETA: 0s - loss: 9.5411e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with acc available, skipping.
# 90/90 [==============================] - 2s 18ms/step - loss: 9.5542e-05 - accuracy: 1.0000 - val_loss: 0.0121 - val_accuracy: 0.9951
# Epoch 33/100
# 89/90 [============================>.] - ETA: 0s - loss: 8.8178e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with acc available, skipping.
# 90/90 [==============================] - 2s 19ms/step - loss: 8.8132e-05 - accuracy: 1.0000 - val_loss: 0.0120 - val_accuracy: 0.9948
# Epoch 34/100
# 89/90 [============================>.] - ETA: 0s - loss: 8.6790e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with acc available, skipping.
# 90/90 [==============================] - 2s 18ms/step - loss: 8.7143e-05 - accuracy: 1.0000 - val_loss: 0.0116 - val_accuracy: 0.9948
# Epoch 35/100
# 89/90 [============================>.] - ETA: 0s - loss: 8.2540e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with acc available, skipping.
# 90/90 [==============================] - 2s 18ms/step - loss: 8.3237e-05 - accuracy: 1.0000 - val_loss: 0.0123 - val_accuracy: 0.9951
# Epoch 36/100
# 89/90 [============================>.] - ETA: 0s - loss: 7.6162e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with acc available, skipping.
# 90/90 [==============================] - 2s 18ms/step - loss: 7.6100e-05 - accuracy: 1.0000 - val_loss: 0.0115 - val_accuracy: 0.9951
# Epoch 37/100
# 89/90 [============================>.] - ETA: 0s - loss: 7.3797e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with acc available, skipping.
# 90/90 [==============================] - 2s 25ms/step - loss: 7.3763e-05 - accuracy: 1.0000 - val_loss: 0.0112 - val_accuracy: 0.9951
# Epoch 38/100
# 89/90 [============================>.] - ETA: 0s - loss: 7.2019e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with acc available, skipping.
# 90/90 [==============================] - 3s 29ms/step - loss: 7.2101e-05 - accuracy: 1.0000 - val_loss: 0.0123 - val_accuracy: 0.9948
# Epoch 39/100
# 89/90 [============================>.] - ETA: 0s - loss: 6.8052e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with acc available, skipping.
# 90/90 [==============================] - 2s 17ms/step - loss: 6.7919e-05 - accuracy: 1.0000 - val_loss: 0.0118 - val_accuracy: 0.9948
# Epoch 40/100
# 89/90 [============================>.] - ETA: 0s - loss: 6.5325e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with acc available, skipping.
# 90/90 [==============================] - 2s 18ms/step - loss: 6.5167e-05 - accuracy: 1.0000 - val_loss: 0.0131 - val_accuracy: 0.9944
# Epoch 41/100
# 89/90 [============================>.] - ETA: 0s - loss: 6.0687e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with acc available, skipping.
# 90/90 [==============================] - 2s 18ms/step - loss: 6.0957e-05 - accuracy: 1.0000 - val_loss: 0.0121 - val_accuracy: 0.9955
# Epoch 42/100
# 89/90 [============================>.] - ETA: 0s - loss: 5.9035e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with acc available, skipping.
# 90/90 [==============================] - 2s 18ms/step - loss: 5.9178e-05 - accuracy: 1.0000 - val_loss: 0.0127 - val_accuracy: 0.9944
# Epoch 43/100
# 89/90 [============================>.] - ETA: 0s - loss: 5.8009e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with acc available, skipping.
# 90/90 [==============================] - 2s 18ms/step - loss: 5.7976e-05 - accuracy: 1.0000 - val_loss: 0.0112 - val_accuracy: 0.9958
# Epoch 44/100
# 89/90 [============================>.] - ETA: 0s - loss: 5.4258e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with acc available, skipping.
# 90/90 [==============================] - 2s 18ms/step - loss: 5.4599e-05 - accuracy: 1.0000 - val_loss: 0.0120 - val_accuracy: 0.9948
# Epoch 45/100
# 89/90 [============================>.] - ETA: 0s - loss: 5.2921e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with acc available, skipping.
# 90/90 [==============================] - 2s 18ms/step - loss: 5.2955e-05 - accuracy: 1.0000 - val_loss: 0.0124 - val_accuracy: 0.9948
# Epoch 46/100
# 89/90 [============================>.] - ETA: 0s - loss: 4.9600e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with acc available, skipping.
# 90/90 [==============================] - 2s 18ms/step - loss: 4.9458e-05 - accuracy: 1.0000 - val_loss: 0.0124 - val_accuracy: 0.9934
# Epoch 47/100
# 89/90 [============================>.] - ETA: 0s - loss: 4.6872e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with acc available, skipping.
# 90/90 [==============================] - 2s 18ms/step - loss: 4.7002e-05 - accuracy: 1.0000 - val_loss: 0.0122 - val_accuracy: 0.9948

# %%
Conv3D_net.evaluate(test_data, test_label, verbose=0)
# Out:
# [0.009796000085771084, 0.996910572052002]

# %%
path = r"/content/drive/My Drive/Marko/Model_learning/GAN/HSI-Classification-GAN/EI_PAPER/weights_and_models"
save = os.path.join(path,"best_Conv3D_net+GAN_data.h5")
Conv3D_net.save_weights(save)

# %%
import matplotlib.pyplot as plt

def plot_learning_curves(history,epoch,min_val,max_val):
        pd.DataFrame(history.history).plot(figsize=(8,5))
        plt.grid(True)
        plt.axis([0, epoch, min_val, max_val])
        plt.show()
plot_learning_curves(history,100,0,1)

# %%
width = 145
height = 145
PATCH_SIZE = 32
numComponents = 30
def Patch(data,height_index,width_index): #0-144 -> 32-176
  height_slice = slice(height_index, height_index+PATCH_SIZE)
  width_slice = slice(width_index, width_index+PATCH_SIZE)
  patch = data[height_slice, width_slice, :] 
  return patch

# %%
# calculate the predicted image
outputs = np.zeros((height,width))
for i in range(height):
    for j in range(width):
        target = fullDataY[int(i), int(j)]
        if target == 0 :
            continue
        else :
            image_patch=Patch(paddedDatax,i,j)
            #print (image_patch.shape)
            X_test_image = image_patch.reshape(1,image_patch.shape[0],image_patch.shape[1],image_patch.shape[2],1).astype('float32')                                   
            prediction = (Conv3D_net.predict(X_test_image))   
            prediction = tf.argmax(prediction, axis=-1).numpy()                     
            outputs[int(i)][int(j)] = prediction+1
print(outputs.shape)
# Out:
# (145, 145)

# %%
# !pip install spectral
# Out:
# Collecting spectral
#   Downloading https://files.pythonhosted.org/packages/f5/ff/f6e238a941ed55079526996fee315fbee5167aaa64de3e64980637ac8f38/spectral-0.21-py3-none-any.whl (187kB)
#      |████████████████████████████████| 194kB 2.0MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from spectral) (1.18.4)
# Installing collected packages: spectral
# Successfully installed spectral-0.21

# %%
import spectral
# Plot the Ground Truth Image
ground_truth = spectral.imshow(classes = fullDataY,figsize =(5,5))

# %%
# Plot the Predicted image
predict_image = spectral.imshow(classes = outputs.astype(int),figsize =(5,5))
