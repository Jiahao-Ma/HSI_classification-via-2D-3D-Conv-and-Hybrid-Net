# %% [markdown]
# ## Load_original_data

# %%
import numpy as np
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import pandas as pd
data = np.load(r"/content/drive/My Drive/Marko/Model_learning/GAN/HSI-Classification-GAN/dataset/ds.npy")
gt = np.load(r"/content/drive/My Drive/Marko/Model_learning/GAN/HSI-Classification-GAN/dataset/gt.npy")
print(data.shape)
print(gt.shape)
# Out:
# (145, 145, 200)
# (145, 145)

# %%
H = data.shape[0]
W = data.shape[1]
#归一化
scaler = StandardScaler()
voxel = scaler.fit_transform(data.reshape(-1, data.shape[-1]))
print(voxel.shape)
#PCA 
pca = PCA(n_components=30)
principalComponents = pca.fit_transform(voxel)
print(principalComponents.shape)
# principalDF = pd.DataFrame(data=principalComponents, columns=["pc%d"%x for x in range(30)])
# print(principalDF)
fullDataX = principalComponents.reshape(H,W,30)
fullDataY = gt
print("fullDataX:",fullDataX.shape)
print("fullDataY:",gt.shape)
# Out:
# (21025, 200)
# (21025, 30)
# fullDataX: (145, 145, 30)
# fullDataY: (145, 145)

# %%
import cv2
from skimage.util import view_as_windows
np.random.seed(666)
print(fullDataX.shape)
#(145,145,30) -> (176,176,30)
paddedDatax = cv2.copyMakeBorder(fullDataX, 16, 15, 16, 15, cv2.BORDER_CONSTANT, value=0)
print(paddedDatax.shape)
#(176,176,30) -> (145,145,1,32,32,30) 176-32+1=145 || 3-3+1=1
X_train = view_as_windows(paddedDatax, (32, 32, 30), step=1).reshape(-1,32,32,30)
#(145,145,1,32,32,30) -> (21025,32,32,03)
y_train = fullDataY.reshape(-1,)
p = np.random.permutation(len(X_train))
X_train=X_train[p]
y_train=y_train[p]
print(X_train.shape)
print(y_train.shape)
# Out:
# (145, 145, 30)
# (176, 176, 30)
# (21025, 32, 32, 30)
# (21025,)

# %%
X_train = X_train[y_train>0,:,:,:]
y_train = y_train[y_train>0]
y_train = y_train - 1 #1-17 -> 0-16
print(X_train.shape)
print(y_train.shape)
data = X_train
label = y_train
# Out:
# (10249, 32, 32, 30)
# (10249,)

# %%
print(np.max(label))
print(np.min(label))

# %% [markdown]
# ## Load_GAN_data

# %%
GAN_data = np.load(r"/content/drive/My Drive/Marko/Model_learning/GAN/HSI-Classification-GAN/EI_PAPER/New_data_generated_by_GAN/generated_data.npy")
GAN_label = np.load(r"/content/drive/My Drive/Marko/Model_learning/GAN/HSI-Classification-GAN/EI_PAPER/New_data_generated_by_GAN/generated_label.npy")
GAN_label = GAN_label - 1
print(GAN_data.shape)
print(GAN_label.shape)
# Out:
# (10249, 32, 32, 30)
# (10249,)

# %%
print(np.max(GAN_label))
print(np.min(GAN_label))

# %%
all_data = np.concatenate((X_train, GAN_data))
all_label = np.concatenate((y_train, GAN_label))
print(all_data.shape)
print(all_label.shape)
# Out:
# (20498, 32, 32, 30)
# (20498,)

# %%
from sklearn.model_selection import train_test_split
import tensorflow as tf

tf.random.set_seed(666)
batch_sz=32
X, test_data, Y, test_label = train_test_split(all_data, all_label, test_size=0.3, random_state=666)
train_data, valid_data, train_label, valid_label = train_test_split(X, Y, test_size=0.2, random_state=666)

train_data = train_data.reshape(-1,32,32,30,1)
valid_data = valid_data.reshape(-1,32,32,30,1)
test_data = test_data.reshape(-1,32,32,30,1)
print(train_data.shape, train_label.shape)
print(valid_data.shape, valid_label.shape)
print(test_data.shape, test_label.shape)
# Out:
# (11478, 32, 32, 30, 1) (11478,)
# (2870, 32, 32, 30, 1) (2870,)
# (6150, 32, 32, 30, 1) (6150,)

# %% [markdown]
# ## Model_define

# %%
W,H,C = X_train.shape[1],X_train.shape[2],X_train.shape[3]
output_size = 16
print(W,H,C)
# Out:
# 32 32 30

# %%
from tensorflow.keras.layers import Dense, Conv3D, Conv2D, Flatten, Reshape, Dropout, Input
from tensorflow.keras.models import Model
# input_layer (None,32,32,30,1)
input_layer = Input(shape=(W,H,C,1))
# convolutional_layer
conv1 = Conv3D(filters=8, kernel_size=(3,3,7), activation="relu")(input_layer)
conv2 = Conv3D(filters=16, kernel_size=(3,3,5), activation="relu")(conv1)
conv3 = Conv3D(filters=32, kernel_size=(3,3,3), activation="relu")(conv2)
print(conv3.shape)
conv3_shape = conv3.shape
conv3 = Reshape((conv3_shape[1],conv3_shape[2],conv3_shape[3]*conv3_shape[4]))(conv3)
conv4 = Conv2D(filters=64, kernel_size=(3,3), activation="relu")(conv3)

flatten = Flatten()(conv4)
# fully_connect_layer
dense1 = Dense(units=256, activation="relu")(flatten)
dense1 = Dropout(0.4)(dense1)
dense2 = Dense(units=128, activation="relu")(dense1)
dense2 = Dropout(0.4)(dense2)
output_layer = Dense(units=output_size, activation="softmax")(dense2)

hybrid_net = Model(input_layer, output_layer)
hybrid_net.summary()
# Out:
# (None, 26, 26, 18, 32)
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 32, 30, 1)]   0
# _________________________________________________________________
# conv3d (Conv3D)              (None, 30, 30, 24, 8)     512
# _________________________________________________________________
# conv3d_1 (Conv3D)            (None, 28, 28, 20, 16)    5776
# _________________________________________________________________
# conv3d_2 (Conv3D)            (None, 26, 26, 18, 32)    13856
# _________________________________________________________________
# reshape (Reshape)            (None, 26, 26, 576)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 24, 24, 64)        331840
# _________________________________________________________________
# flatten (Flatten)            (None, 36864)             0
# _________________________________________________________________
# dense (Dense)                (None, 256)               9437440
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 16)                2064
# =================================================================
# Total params: 9,824,384
# Trainable params: 9,824,384
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras import optimizers
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
import os 
path = r"/content/drive/My Drive/Marko/Model_learning/GAN/HSI-Classification-GAN/EI_PAPER/weights_and_models"
save = os.path.join(path,"best_hybrid_net+GAN_data.h5")

adam = optimizers.Adam(learning_rate=0.0005, decay=1e-6)
checkpoint = ModelCheckpoint(save, monitor='acc', verbose=0, save_best_only=True, mode='max')
earlystopping = EarlyStopping(patience=10, min_delta=1e-4)
callbacks_list = [checkpoint,earlystopping]
hybrid_net.compile(loss='sparse_categorical_crossentropy', optimizer=adam, metrics=['accuracy'])
hybrid_net.load_weights(save)

# %%
batch_sz=128
os.environ["TF_CPP_MIN_LOG_LEVEL"]="3"
history = hybrid_net.fit(train_data, train_label,
              epochs=50,
              batch_size=batch_sz,
              validation_data=(valid_data, valid_label),
              callbacks=callbacks_list)
# Out:
# Epoch 1/50
# 90/90 [==============================] - ETA: 0s - loss: 0.0076 - accuracy: 0.9979WARNING:tensorflow:Can save best model only with acc available, skipping.
# 90/90 [==============================] - 11s 123ms/step - loss: 0.0076 - accuracy: 0.9979 - val_loss: 3.5030e-04 - val_accuracy: 1.0000
# Epoch 2/50
# 90/90 [==============================] - ETA: 0s - loss: 0.0026 - accuracy: 0.9994WARNING:tensorflow:Can save best model only with acc available, skipping.
# 90/90 [==============================] - 11s 118ms/step - loss: 0.0026 - accuracy: 0.9994 - val_loss: 5.0625e-05 - val_accuracy: 1.0000
# Epoch 3/50
# 90/90 [==============================] - ETA: 0s - loss: 0.0033 - accuracy: 0.9993WARNING:tensorflow:Can save best model only with acc available, skipping.
# 90/90 [==============================] - 11s 119ms/step - loss: 0.0033 - accuracy: 0.9993 - val_loss: 1.1084e-04 - val_accuracy: 1.0000
# Epoch 4/50
# 90/90 [==============================] - ETA: 0s - loss: 0.0050 - accuracy: 0.9994WARNING:tensorflow:Can save best model only with acc available, skipping.
# 90/90 [==============================] - 11s 119ms/step - loss: 0.0050 - accuracy: 0.9994 - val_loss: 7.1342e-05 - val_accuracy: 1.0000
# Epoch 5/50
# 90/90 [==============================] - ETA: 0s - loss: 0.0026 - accuracy: 0.9994WARNING:tensorflow:Can save best model only with acc available, skipping.
# 90/90 [==============================] - 11s 119ms/step - loss: 0.0026 - accuracy: 0.9994 - val_loss: 2.7701e-05 - val_accuracy: 1.0000
# Epoch 6/50
# 90/90 [==============================] - ETA: 0s - loss: 0.0035 - accuracy: 0.9992WARNING:tensorflow:Can save best model only with acc available, skipping.
# 90/90 [==============================] - 11s 117ms/step - loss: 0.0035 - accuracy: 0.9992 - val_loss: 5.4877e-04 - val_accuracy: 0.9997
# Epoch 7/50
# 90/90 [==============================] - ETA: 0s - loss: 0.0040 - accuracy: 0.9993WARNING:tensorflow:Can save best model only with acc available, skipping.
# 90/90 [==============================] - 11s 118ms/step - loss: 0.0040 - accuracy: 0.9993 - val_loss: 6.4624e-05 - val_accuracy: 1.0000
# Epoch 8/50
# 90/90 [==============================] - ETA: 0s - loss: 0.0038 - accuracy: 0.9996WARNING:tensorflow:Can save best model only with acc available, skipping.
# 90/90 [==============================] - 11s 118ms/step - loss: 0.0038 - accuracy: 0.9996 - val_loss: 6.0268e-05 - val_accuracy: 1.0000
# Epoch 9/50
# 90/90 [==============================] - ETA: 0s - loss: 0.0021 - accuracy: 0.9997WARNING:tensorflow:Can save best model only with acc available, skipping.
# 90/90 [==============================] - 11s 118ms/step - loss: 0.0021 - accuracy: 0.9997 - val_loss: 5.9364e-05 - val_accuracy: 1.0000
# Epoch 10/50
# 90/90 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 0.9996WARNING:tensorflow:Can save best model only with acc available, skipping.
# 90/90 [==============================] - 11s 119ms/step - loss: 0.0011 - accuracy: 0.9996 - val_loss: 5.6703e-05 - val_accuracy: 1.0000
# Epoch 11/50
# 90/90 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 0.9997WARNING:tensorflow:Can save best model only with acc available, skipping.
# 90/90 [==============================] - 11s 119ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 8.6071e-06 - val_accuracy: 1.0000
# Epoch 12/50
# 90/90 [==============================] - ETA: 0s - loss: 3.8349e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with acc available, skipping.
# 90/90 [==============================] - 11s 121ms/step - loss: 3.8349e-04 - accuracy: 1.0000 - val_loss: 3.8173e-06 - val_accuracy: 1.0000

# %%
hybrid_net.evaluate(test_data, test_label, verbose=0)
# Out:
# [0.00034468647208996117, 0.9998373985290527]

# %%
path = r"/content/drive/My Drive/Marko/Model_learning/GAN/HSI-Classification-GAN/EI_PAPER/weights_and_models"
save = os.path.join(path,"best_hybrid_net+GAN_data.h5")
hybrid_net.save_weights(save)

# %%
width = 145
height = 145
PATCH_SIZE = 32
numComponents = 30
def Patch(data,height_index,width_index): #0-144 -> 32-176
  height_slice = slice(height_index, height_index+PATCH_SIZE)
  width_slice = slice(width_index, width_index+PATCH_SIZE)
  patch = data[height_slice, width_slice, :] 
  return patch

# %%
# calculate the predicted image
outputs = np.zeros((height,width))
for i in range(height):
    for j in range(width):
        target = fullDataY[int(i), int(j)]
        if target == 0 :
            continue
        else :
            image_patch=Patch(paddedDatax,i,j)
            #print (image_patch.shape)
            X_test_image = image_patch.reshape(1,image_patch.shape[0],image_patch.shape[1],image_patch.shape[2],1).astype('float32')                                   
            prediction = (hybrid_net.predict(X_test_image))   
            prediction = tf.argmax(prediction, axis=-1).numpy()                     
            outputs[int(i)][int(j)] = prediction+1
print(outputs.shape)
# Out:
# (145, 145)

# %%
# !pip install spectral
# Out:
# Collecting spectral
#   Downloading https://files.pythonhosted.org/packages/f5/ff/f6e238a941ed55079526996fee315fbee5167aaa64de3e64980637ac8f38/spectral-0.21-py3-none-any.whl (187kB)
#      |████████████████████████████████| 194kB 4.9MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from spectral) (1.18.4)
# Installing collected packages: spectral
# Successfully installed spectral-0.21

# %%
import spectral
# Plot the Ground Truth Image
ground_truth = spectral.imshow(classes = fullDataY,figsize =(5,5))

# %%
# Plot the Predicted image
predict_image = spectral.imshow(classes = outputs.astype(int),figsize =(5,5))

# %%
from sklearn.metrics import classification_report, confusion_matrix
def report(X_test, y_test, model):
  target_names = ['Alfalfa', 'Corn-notill', 'Corn-mintill', 'Corn'
              ,'Grass-pasture', 'Grass-trees', 'Grass-pasture-mowed', 
              'Hay-windrowed', 'Oats', 'Soybean-notill', 'Soybean-mintill',
              'Soybean-clean', 'Wheat', 'Woods', 'Buildings-Grass-Trees-Drives',
              'Stone-Steel-Towers']
  y_pred = np.argmax(model.predict(X_test),axis=1)
  classification = classification_report(y_test, y_pred, target_names=target_names)
  confusion = confusion_matrix(y_test, y_pred)
  score = model.evaluate(X_test, y_test, batch_size=32)
  loss, accuracy = score[0], score[1]
  return classification, confusion, loss, accuracy
print(X_train.shape)
print(y_train.shape)
X_train = X_train.reshape(-1,32,32,30,1)
classification, confusion, loss, accuracy = report(X_train, y_train, hybrid_net)
# Out:
# (10249, 32, 32, 30)
# (10249,)
# 321/321 [==============================] - 4s 11ms/step - loss: 1.5469e-04 - accuracy: 0.9999

# %%
print("{}".format(classification))
# Out:
#                               precision    recall  f1-score   support
#
#                      Alfalfa       1.00      1.00      1.00        46
#                  Corn-notill       1.00      1.00      1.00      1428
#                 Corn-mintill       1.00      1.00      1.00       830
#                         Corn       1.00      1.00      1.00       237
#                Grass-pasture       1.00      1.00      1.00       483
#                  Grass-trees       1.00      1.00      1.00       730
#          Grass-pasture-mowed       1.00      1.00      1.00        28
#                Hay-windrowed       1.00      1.00      1.00       478
#                         Oats       1.00      1.00      1.00        20
#               Soybean-notill       1.00      1.00      1.00       972
#              Soybean-mintill       1.00      1.00      1.00      2455
#                Soybean-clean       1.00      1.00      1.00       593
#                        Wheat       1.00      1.00      1.00       205
#                        Woods       1.00      1.00      1.00      1265
# Buildings-Grass-Trees-Drives       1.00      1.00      1.00       386
#           Stone-Steel-Towers       1.00      1.00      1.00        93
#
#                     accuracy                           1.00     10249
#                    macro avg       1.00      1.00      1.00     10249
#                 weighted avg       1.00      1.00      1.00     10249
