# %% [markdown]
# ## Load_data

# %%
import numpy as np
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import pandas as pd
data = np.load(r"/content/drive/My Drive/Marko/Model_learning/GAN/HSI-Classification-GAN/dataset/ds.npy")
gt = np.load(r"/content/drive/My Drive/Marko/Model_learning/GAN/HSI-Classification-GAN/dataset/gt.npy")
print(data.shape)
print(gt.shape)
# Out:
# (145, 145, 200)
# (145, 145)

# %%
H = data.shape[0]
W = data.shape[1]
#归一化
scaler = StandardScaler()
voxel = scaler.fit_transform(data.reshape(-1, data.shape[-1]))
print(voxel.shape)
#PCA 
pca = PCA(n_components=30)
principalComponents = pca.fit_transform(voxel)
print(principalComponents.shape)
# principalDF = pd.DataFrame(data=principalComponents, columns=["pc%d"%x for x in range(30)])
# print(principalDF)
fullDataX = principalComponents.reshape(H,W,30)
fullDataY = gt
print("fullDataX:",fullDataX.shape)
print("fullDataY:",gt.shape)
# Out:
# (21025, 200)
# (21025, 30)
# fullDataX: (145, 145, 30)
# fullDataY: (145, 145)

# %%
import cv2
from skimage.util import view_as_windows
np.random.seed(666)
print(fullDataX.shape)
#(145,145,30) -> (176,176,30)
paddedDatax = cv2.copyMakeBorder(fullDataX, 16, 15, 16, 15, cv2.BORDER_CONSTANT, value=0)
print(paddedDatax.shape)
#(176,176,30) -> (145,145,1,32,32,30) 176-32+1=145 || 3-3+1=1
X_train = view_as_windows(paddedDatax, (32, 32, 30), step=1).reshape(-1,32,32,30)
#(145,145,1,32,32,30) -> (21025,32,32,03)
y_train = fullDataY.reshape(-1,)
p = np.random.permutation(len(X_train))
X_train=X_train[p]
y_train=y_train[p]
print(X_train.shape)
print(y_train.shape)
# Out:
# (145, 145, 30)
# (176, 176, 30)
# (21025, 32, 32, 30)
# (21025,)

# %%
X_train = X_train[y_train>0,:,:,:]
y_train = y_train[y_train>0]
y_train = y_train - 1 #1-17 -> 0-16
print(X_train.shape)
print(y_train.shape)
data = X_train
label = y_train
# Out:
# (10249, 32, 32, 30)
# (10249,)

# %%
from sklearn.model_selection import train_test_split
import tensorflow as tf

tf.random.set_seed(666)
batch_sz=128
X, test_data, Y, test_label = train_test_split(data, label, test_size=0.1, random_state=666)
train_data, valid_data, train_label, valid_label = train_test_split(X, Y, test_size=0.2, random_state=666)

print(train_data.shape, train_label.shape)
print(valid_data.shape, valid_label.shape)
print(test_data.shape, test_label.shape)
# Out:
# (7379, 32, 32, 30) (7379,)
# (1845, 32, 32, 30) (1845,)
# (1025, 32, 32, 30) (1025,)

# %% [markdown]
# ## Model_define

# %%
from tensorflow.keras.layers import Dense, Conv3D, Conv2D, Flatten, Reshape, Dropout, Input, Activation, BatchNormalization
from tensorflow.keras.models import Model
import tensorflow as tf
channel = 30
#input_layer (None,32,32,30)
input_layer = Input(shape=(32,32,30))
#Conv_layer
Conv1 = Conv2D(filters=60, kernel_size=(3,3),activation="relu")(input_layer)
Conv2 = Conv2D(filters=90, kernel_size=(3,3),activation="relu")(Conv1)

#fully_Connected_layer
flatten_layer = Flatten()(Conv1)
Dense1 = Dense(units=160, activation="relu")(flatten_layer)
Dense1 = Dropout(0.25)(Dense1)
output_layer = Dense(units=16, activation="softmax")(Dense1)

Conv2D_net = Model(input_layer, output_layer)

# %%
Conv2D_net.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 32, 32, 30)]      0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 30, 30, 60)        16260
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 54000)             0
# _________________________________________________________________
# dense_4 (Dense)              (None, 160)               8640160
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 160)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 16)                2576
# =================================================================
# Total params: 8,658,996
# Trainable params: 8,658,996
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras import optimizers
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
import os 
path = r"/content/drive/My Drive/Marko/Model_learning/GAN/HSI-Classification-GAN/EI_PAPER/weights_and_models"
save = os.path.join(path,"best_Conv2D_net.h5")

adam = optimizers.Adam(learning_rate=0.0005, decay=1e-6)
checkpoint = ModelCheckpoint(save, monitor='acc', verbose=0, save_best_only=True, mode='max')
earlystopping = EarlyStopping(patience=10, min_delta=1e-4)
callbacks_list = [checkpoint,earlystopping]
Conv2D_net.compile(loss='sparse_categorical_crossentropy', optimizer=adam, metrics=['accuracy'])

# %%
os.environ["TF_CPP_MIN_LOG_LEVEL"]="3"
history = Conv2D_net.fit(train_data, train_label,
              epochs=100,
              batch_size=batch_sz,
              validation_data=(valid_data, valid_label),
              callbacks=callbacks_list)
# Out:
# Epoch 1/100
# 56/58 [===========================>..] - ETA: 0s - loss: 3.8086 - accuracy: 0.5724WARNING:tensorflow:Can save best model only with acc available, skipping.
# 58/58 [==============================] - 1s 17ms/step - loss: 3.7164 - accuracy: 0.5795 - val_loss: 0.3595 - val_accuracy: 0.8770
# Epoch 2/100
# 56/58 [===========================>..] - ETA: 0s - loss: 0.3235 - accuracy: 0.8881WARNING:tensorflow:Can save best model only with acc available, skipping.
# 58/58 [==============================] - 1s 15ms/step - loss: 0.3195 - accuracy: 0.8902 - val_loss: 0.0750 - val_accuracy: 0.9897
# Epoch 3/100
# 56/58 [===========================>..] - ETA: 0s - loss: 0.1512 - accuracy: 0.9464WARNING:tensorflow:Can save best model only with acc available, skipping.
# 58/58 [==============================] - 1s 15ms/step - loss: 0.1502 - accuracy: 0.9466 - val_loss: 0.0361 - val_accuracy: 0.9946
# Epoch 4/100
# 56/58 [===========================>..] - ETA: 0s - loss: 0.0901 - accuracy: 0.9724WARNING:tensorflow:Can save best model only with acc available, skipping.
# 58/58 [==============================] - 1s 16ms/step - loss: 0.0905 - accuracy: 0.9718 - val_loss: 0.0142 - val_accuracy: 0.9984
# Epoch 5/100
# 56/58 [===========================>..] - ETA: 0s - loss: 0.0613 - accuracy: 0.9819WARNING:tensorflow:Can save best model only with acc available, skipping.
# 58/58 [==============================] - 1s 15ms/step - loss: 0.0613 - accuracy: 0.9817 - val_loss: 0.0096 - val_accuracy: 0.9984
# Epoch 6/100
# 56/58 [===========================>..] - ETA: 0s - loss: 0.0575 - accuracy: 0.9823WARNING:tensorflow:Can save best model only with acc available, skipping.
# 58/58 [==============================] - 1s 15ms/step - loss: 0.0571 - accuracy: 0.9822 - val_loss: 0.0081 - val_accuracy: 0.9984
# Epoch 7/100
# 56/58 [===========================>..] - ETA: 0s - loss: 0.0499 - accuracy: 0.9841WARNING:tensorflow:Can save best model only with acc available, skipping.
# 58/58 [==============================] - 1s 15ms/step - loss: 0.0498 - accuracy: 0.9840 - val_loss: 0.0085 - val_accuracy: 0.9989
# Epoch 8/100
# 56/58 [===========================>..] - ETA: 0s - loss: 0.0403 - accuracy: 0.9860WARNING:tensorflow:Can save best model only with acc available, skipping.
# 58/58 [==============================] - 1s 15ms/step - loss: 0.0400 - accuracy: 0.9860 - val_loss: 0.0111 - val_accuracy: 0.9978
# Epoch 9/100
# 55/58 [===========================>..] - ETA: 0s - loss: 0.0325 - accuracy: 0.9895WARNING:tensorflow:Can save best model only with acc available, skipping.
# 58/58 [==============================] - 1s 15ms/step - loss: 0.0326 - accuracy: 0.9894 - val_loss: 0.0035 - val_accuracy: 0.9995
# Epoch 10/100
# 56/58 [===========================>..] - ETA: 0s - loss: 0.0353 - accuracy: 0.9887WARNING:tensorflow:Can save best model only with acc available, skipping.
# 58/58 [==============================] - 1s 16ms/step - loss: 0.0350 - accuracy: 0.9889 - val_loss: 0.0044 - val_accuracy: 0.9984
# Epoch 11/100
# 56/58 [===========================>..] - ETA: 0s - loss: 0.0262 - accuracy: 0.9915WARNING:tensorflow:Can save best model only with acc available, skipping.
# 58/58 [==============================] - 1s 15ms/step - loss: 0.0259 - accuracy: 0.9916 - val_loss: 0.0042 - val_accuracy: 0.9984
# Epoch 12/100
# 55/58 [===========================>..] - ETA: 0s - loss: 0.0286 - accuracy: 0.9893WARNING:tensorflow:Can save best model only with acc available, skipping.
# 58/58 [==============================] - 1s 15ms/step - loss: 0.0291 - accuracy: 0.9892 - val_loss: 0.0036 - val_accuracy: 0.9984
# Epoch 13/100
# 56/58 [===========================>..] - ETA: 0s - loss: 0.0247 - accuracy: 0.9922WARNING:tensorflow:Can save best model only with acc available, skipping.
# 58/58 [==============================] - 1s 15ms/step - loss: 0.0243 - accuracy: 0.9924 - val_loss: 0.0022 - val_accuracy: 0.9995
# Epoch 14/100
# 56/58 [===========================>..] - ETA: 0s - loss: 0.0203 - accuracy: 0.9923WARNING:tensorflow:Can save best model only with acc available, skipping.
# 58/58 [==============================] - 1s 15ms/step - loss: 0.0206 - accuracy: 0.9921 - val_loss: 0.0020 - val_accuracy: 0.9995
# Epoch 15/100
# 56/58 [===========================>..] - ETA: 0s - loss: 0.0192 - accuracy: 0.9933WARNING:tensorflow:Can save best model only with acc available, skipping.
# 58/58 [==============================] - 1s 15ms/step - loss: 0.0192 - accuracy: 0.9934 - val_loss: 0.0062 - val_accuracy: 0.9973
# Epoch 16/100
# 56/58 [===========================>..] - ETA: 0s - loss: 0.0174 - accuracy: 0.9941WARNING:tensorflow:Can save best model only with acc available, skipping.
# 58/58 [==============================] - 1s 15ms/step - loss: 0.0178 - accuracy: 0.9940 - val_loss: 0.0092 - val_accuracy: 0.9984
# Epoch 17/100
# 56/58 [===========================>..] - ETA: 0s - loss: 0.0131 - accuracy: 0.9961WARNING:tensorflow:Can save best model only with acc available, skipping.
# 58/58 [==============================] - 1s 15ms/step - loss: 0.0131 - accuracy: 0.9962 - val_loss: 0.0012 - val_accuracy: 0.9995
# Epoch 18/100
# 56/58 [===========================>..] - ETA: 0s - loss: 0.0239 - accuracy: 0.9920WARNING:tensorflow:Can save best model only with acc available, skipping.
# 58/58 [==============================] - 1s 15ms/step - loss: 0.0233 - accuracy: 0.9923 - val_loss: 0.0033 - val_accuracy: 0.9989
# Epoch 19/100
# 56/58 [===========================>..] - ETA: 0s - loss: 0.0179 - accuracy: 0.9939WARNING:tensorflow:Can save best model only with acc available, skipping.
# 58/58 [==============================] - 1s 15ms/step - loss: 0.0177 - accuracy: 0.9939 - val_loss: 0.0017 - val_accuracy: 0.9995
# Epoch 20/100
# 56/58 [===========================>..] - ETA: 0s - loss: 0.0248 - accuracy: 0.9934WARNING:tensorflow:Can save best model only with acc available, skipping.
# 58/58 [==============================] - 1s 15ms/step - loss: 0.0244 - accuracy: 0.9935 - val_loss: 0.0065 - val_accuracy: 0.9978
# Epoch 21/100
# 56/58 [===========================>..] - ETA: 0s - loss: 0.0160 - accuracy: 0.9951WARNING:tensorflow:Can save best model only with acc available, skipping.
# 58/58 [==============================] - 1s 15ms/step - loss: 0.0157 - accuracy: 0.9953 - val_loss: 0.0051 - val_accuracy: 0.9984
# Epoch 22/100
# 56/58 [===========================>..] - ETA: 0s - loss: 0.0186 - accuracy: 0.9936WARNING:tensorflow:Can save best model only with acc available, skipping.
# 58/58 [==============================] - 1s 15ms/step - loss: 0.0187 - accuracy: 0.9936 - val_loss: 8.2203e-04 - val_accuracy: 0.9995
# Epoch 23/100
# 56/58 [===========================>..] - ETA: 0s - loss: 0.0141 - accuracy: 0.9948WARNING:tensorflow:Can save best model only with acc available, skipping.
# 58/58 [==============================] - 1s 15ms/step - loss: 0.0139 - accuracy: 0.9950 - val_loss: 0.0029 - val_accuracy: 0.9989
# Epoch 24/100
# 56/58 [===========================>..] - ETA: 0s - loss: 0.0134 - accuracy: 0.9964WARNING:tensorflow:Can save best model only with acc available, skipping.
# 58/58 [==============================] - 1s 15ms/step - loss: 0.0135 - accuracy: 0.9962 - val_loss: 5.2517e-04 - val_accuracy: 1.0000
# Epoch 25/100
# 56/58 [===========================>..] - ETA: 0s - loss: 0.0129 - accuracy: 0.9964WARNING:tensorflow:Can save best model only with acc available, skipping.
# 58/58 [==============================] - 1s 15ms/step - loss: 0.0133 - accuracy: 0.9962 - val_loss: 0.0049 - val_accuracy: 0.9989
# Epoch 26/100
# 56/58 [===========================>..] - ETA: 0s - loss: 0.0159 - accuracy: 0.9940WARNING:tensorflow:Can save best model only with acc available, skipping.
# 58/58 [==============================] - 1s 15ms/step - loss: 0.0155 - accuracy: 0.9942 - val_loss: 0.0056 - val_accuracy: 0.9978
# Epoch 27/100
# 56/58 [===========================>..] - ETA: 0s - loss: 0.0123 - accuracy: 0.9948WARNING:tensorflow:Can save best model only with acc available, skipping.
# 58/58 [==============================] - 1s 15ms/step - loss: 0.0127 - accuracy: 0.9949 - val_loss: 0.0067 - val_accuracy: 0.9973
# Epoch 28/100
# 56/58 [===========================>..] - ETA: 0s - loss: 0.0201 - accuracy: 0.9947WARNING:tensorflow:Can save best model only with acc available, skipping.
# 58/58 [==============================] - 1s 16ms/step - loss: 0.0196 - accuracy: 0.9949 - val_loss: 0.0039 - val_accuracy: 0.9978
# Epoch 29/100
# 56/58 [===========================>..] - ETA: 0s - loss: 0.0123 - accuracy: 0.9965WARNING:tensorflow:Can save best model only with acc available, skipping.
# 58/58 [==============================] - 1s 16ms/step - loss: 0.0119 - accuracy: 0.9966 - val_loss: 0.0117 - val_accuracy: 0.9978
# Epoch 30/100
# 56/58 [===========================>..] - ETA: 0s - loss: 0.0287 - accuracy: 0.9911WARNING:tensorflow:Can save best model only with acc available, skipping.
# 58/58 [==============================] - 1s 15ms/step - loss: 0.0288 - accuracy: 0.9912 - val_loss: 0.0053 - val_accuracy: 0.9989
# Epoch 31/100
# 56/58 [===========================>..] - ETA: 0s - loss: 0.0271 - accuracy: 0.9916WARNING:tensorflow:Can save best model only with acc available, skipping.
# 58/58 [==============================] - 1s 15ms/step - loss: 0.0266 - accuracy: 0.9917 - val_loss: 0.0174 - val_accuracy: 0.9940
# Epoch 32/100
# 56/58 [===========================>..] - ETA: 0s - loss: 0.0143 - accuracy: 0.9948WARNING:tensorflow:Can save best model only with acc available, skipping.
# 58/58 [==============================] - 1s 15ms/step - loss: 0.0139 - accuracy: 0.9950 - val_loss: 0.0038 - val_accuracy: 0.9984
# Epoch 33/100
# 56/58 [===========================>..] - ETA: 0s - loss: 0.0135 - accuracy: 0.9957WARNING:tensorflow:Can save best model only with acc available, skipping.
# 58/58 [==============================] - 1s 15ms/step - loss: 0.0134 - accuracy: 0.9957 - val_loss: 0.0054 - val_accuracy: 0.9978
# Epoch 34/100
# 56/58 [===========================>..] - ETA: 0s - loss: 0.0082 - accuracy: 0.9969WARNING:tensorflow:Can save best model only with acc available, skipping.
# 58/58 [==============================] - 1s 15ms/step - loss: 0.0094 - accuracy: 0.9966 - val_loss: 0.0033 - val_accuracy: 0.9989

# %%
Conv2D_net.save_weights(save)

# %%
Conv2D_net.evaluate(test_data, test_label, verbose=0)
# Out:
# [0.002200032351538539, 0.9990243911743164]

# %%
import matplotlib.pyplot as plt

def plot_learning_curves(history,epoch,min_val,max_val):
        pd.DataFrame(history.history).plot(figsize=(8,5))
        plt.grid(True)
        plt.axis([0, epoch, min_val, max_val])
        plt.show()
plot_learning_curves(history,30,0,1)

# %%
width = 145
height = 145
PATCH_SIZE = 32
numComponents = 30
def Patch(data,height_index,width_index): #0-144 -> 32-176
  height_slice = slice(height_index, height_index+PATCH_SIZE)
  width_slice = slice(width_index, width_index+PATCH_SIZE)
  patch = data[height_slice, width_slice, :] 
  return patch

# %%
# calculate the predicted image
outputs = np.zeros((height,width))
for i in range(height):
    for j in range(width):
        target = fullDataY[int(i), int(j)]
        if target == 0 :
            continue
        else :
            image_patch=Patch(paddedDatax,i,j)
            #print (image_patch.shape)
            X_test_image = image_patch.reshape(1,image_patch.shape[0],image_patch.shape[1],image_patch.shape[2]).astype('float32')                                   
            prediction = (Conv2D_net.predict(X_test_image))   
            prediction = tf.argmax(prediction, axis=-1).numpy()                     
            outputs[int(i)][int(j)] = prediction+1
print(outputs.shape)
# Out:
# (145, 145)

# %%
# !pip install spectral
# Out:
# Collecting spectral
#   Downloading https://files.pythonhosted.org/packages/f5/ff/f6e238a941ed55079526996fee315fbee5167aaa64de3e64980637ac8f38/spectral-0.21-py3-none-any.whl (187kB)
#      |████████████████████████████████| 194kB 4.7MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from spectral) (1.18.4)
# Installing collected packages: spectral
# Successfully installed spectral-0.21

# %%
import spectral
# Plot the Ground Truth Image
ground_truth = spectral.imshow(classes = fullDataY,figsize =(5,5))

# %%
# Plot the Predicted image
predict_image = spectral.imshow(classes = outputs.astype(int),figsize =(5,5))

# %%
from sklearn.metrics import classification_report, confusion_matrix
def report(X_test, y_test, model):
  target_names = ['Alfalfa', 'Corn-notill', 'Corn-mintill', 'Corn'
              ,'Grass-pasture', 'Grass-trees', 'Grass-pasture-mowed', 
              'Hay-windrowed', 'Oats', 'Soybean-notill', 'Soybean-mintill',
              'Soybean-clean', 'Wheat', 'Woods', 'Buildings-Grass-Trees-Drives',
              'Stone-Steel-Towers']
  y_pred = np.argmax(model.predict(X_test),axis=1)
  classification = classification_report(y_test, y_pred, target_names=target_names)
  confusion = confusion_matrix(y_test, y_pred)
  score = model.evaluate(X_test, y_test, batch_size=32)
  loss, accuracy = score[0], score[1]
  return classification, confusion, loss, accuracy
print(X_train.shape)
print(y_train.shape)
X_train = X_train.reshape(-1,32,32,30,1)
Conv2D_net.load_weights(r"/content/drive/My Drive/Marko/Model_learning/GAN/HSI-Classification-GAN/EI_PAPER/weights_and_models/best_Conv2D_net.h5")
classification, confusion, loss, accuracy = report(X_train, y_train, Conv2D_net)
# Out:
# (10249, 32, 32, 30, 1)
# (10249,)
# 321/321 [==============================] - 7s 20ms/step - loss: 7.5432e-04 - accuracy: 0.9997

# %%
print("{}".format(classification))
# Out:
#                               precision    recall  f1-score   support
#
#                      Alfalfa       1.00      1.00      1.00        46
#                  Corn-notill       1.00      1.00      1.00      1428
#                 Corn-mintill       1.00      1.00      1.00       830
#                         Corn       1.00      1.00      1.00       237
#                Grass-pasture       1.00      1.00      1.00       483
#                  Grass-trees       1.00      1.00      1.00       730
#          Grass-pasture-mowed       1.00      1.00      1.00        28
#                Hay-windrowed       1.00      1.00      1.00       478
#                         Oats       1.00      1.00      1.00        20
#               Soybean-notill       1.00      1.00      1.00       972
#              Soybean-mintill       1.00      1.00      1.00      2455
#                Soybean-clean       1.00      1.00      1.00       593
#                        Wheat       1.00      1.00      1.00       205
#                        Woods       1.00      1.00      1.00      1265
# Buildings-Grass-Trees-Drives       1.00      1.00      1.00       386
#           Stone-Steel-Towers       1.00      1.00      1.00        93
#
#                     accuracy                           1.00     10249
#                    macro avg       1.00      1.00      1.00     10249
#                 weighted avg       1.00      1.00      1.00     10249
